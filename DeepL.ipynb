# %%
import pandas as pd
d=pd.read_csv('crowdsourcedquestsions.csv',encoding='windows-1252')

# %%
d['Qx']
# Out:
# 0               Under what circumstances do those wit...
# 1              Is diabetes something that can be over...
# 2              What kind of special diet does someone...
# 3              Under what circumstances is a ketogeni...
# 4              To what extent does it exist on a spec...
#                              ...
# 279     i understand i can be predisposed to diabetes...
# 280     would taking both a pill and insulin shots he...
# 281      wha does diabetes do that causes the high pr...
# 282     How does diabetes affect the circulation whic...
# 283     Since it seems to develop spontaneously, does...
# Name: Qx, Length: 284, dtype: object

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'person_ID', 'qx_ID', 'Qx', 'CAUSE', 'RISK',
#        'PREVENTION', 'DIAGNOSIS', 'MANIFESTATIONS', 'TREATMENT', 'ANATOMY',
#        'CURE', 'DIET', 'EXERCISE', 'WEIGHT', 'SELF-MANAGEMENT',
#        'DISEASE COMPLICATIONS', 'TREATMENT COMPLICATIONS',
#        'PERSON or ORGANIZATION', 'PROGNOSIS',
#        'DISTRIBUTION of a DISEASE in a POPULATION', 'INHERITANCE PATTERNS',
#        'RESEARCH', 'PSYCHOSOCIAL', 'Own HEALTH RECORD RELATED', 'OTHER'],
#       dtype='object')

# %%
df=pd.read_csv('clinicquestions.csv',encoding='windows-1252')

# %%
df=pd.concat([df, d])

# %%
for d in df['Qx'][:2]:
    print(d)
# Out:
# Could problem with balance be related to hypos? My GP thinks so and has reduced my gliclizide
# Why has Victoza resulted in increased appetite and weight gain?

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
#warnings.filterwarnings("ignore")

# %%
quest="Could problem with balance be related to hypos? My GP thinks so and has reduced my gliclizide"

# %%
driver = webdriver.Chrome('chromedriver_win32/chromedriver')
driver.get('https://www.deepl.com/translator#en/fr/')
place=driver.find_element(By.XPATH,'//*[@id="panelTranslateText"]/div[1]/div[2]/section[1]/div[3]/div[2]/d-textarea/div/p')
place.send_keys(str(quest))
place.send_keys(Keys.RETURN)
time.sleep(10)
driver.find_element(By.XPATH,'//*[@id="translator-source-clear-button"]').click()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4032\1982879320.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver_win32/chromedriver')
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 driver = webdriver.Chrome('chromedriver_win32/chromedriver')
#       2 driver.get('https://www.deepl.com/translator#en/fr/')
# ----> 3 place=driver.find_element(By.XPATH,'//*[@id="panelTranslateText"]/div[1]/div[2]/section[1]/div[3]/div[2]/d-textarea/div/p')
#       4 place.send_keys(str(quest))
#       5 place.send_keys(Keys.RETURN)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# ...

# %%
print(len(df['Qx']))
resu=[]
driver = webdriver.Chrome('chromedriver_win32/chromedriver')
driver.get('https://www.deepl.com/translator#en/fr/')
for quest in df['Qx']:
    
    place=driver.find_element(By.XPATH,'//*[@id="panelTranslateText"]/div[1]/div[2]/section[1]/div[3]/div[2]/d-textarea/div/p')
    place.send_keys(str(quest))
    place.send_keys(Keys.RETURN)
    time.sleep(20) 

    re=driver.find_element(By.XPATH,'//*[@id="panelTranslateText"]/div[1]/div[2]/section[2]/div[3]/div[1]/d-textarea/div/p[1]/span').text
    print(quest,'##',re)
    resu.append(re)
    driver.find_element(By.XPATH,'//*[@id="translator-source-clear-button"]').click()
    
driver.quit()
print(len(resu))
# Out:
# 436
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13820\2560133055.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver_win32/chromedriver')
# Could problem with balance be related to hypos? My GP thinks so and has reduced my gliclizide ## Les problèmes d'équilibre peuvent-ils être liés aux hypos ?
# Why has Victoza resulted in increased appetite and weight gain? ## Pourquoi Victoza a-t-il entraîné une augmentation de l'appétit et une prise de poids ?
#  How do I stop need for sugar / chocolate? ##  Comment arrêter le besoin de sucre / de chocolat ?
# How is my blood sugar controlled? Do I have to do anything more? ## Comment ma glycémie est-elle contrôlée ?
#  Why is there such a difference in blood tests?  ##  Pourquoi y a-t-il une telle différence entre les analyses de sang ?
# ...

# %%
d=pd.DataFrame(resu,colu)
# Out:
# Les problèmes d'équilibre peuvent-ils être liés aux hypos ?  0
# Pourquoi Victoza a-t-il entraîné une augmentation de l'appétit et une prise de poids ? 1
#  Comment mettre fin au besoin de sucre ou de chocolat ? 2
# Comment ma glycémie est-elle contrôlée ?  3
#  Pourquoi y a-t-il une telle différence entre les analyses de sang ?  4
# Mon contrôle a été bon jusqu'à présent, mais est-il susceptible de se détériorer avec l'âge, à mesure que mon métabolisme se modifie ? 5
# Comment puis-je mieux contrôler ma glycémie ?  6
#  Si je ne prends pas de médicaments, est-ce que je peux garder le contrôle de la maladie en perdant du poids ? 7
# Pourquoi dois-je prendre de l'insuline ? 8
# Pourquoi mes tablettes ne fonctionnent-elles plus ? 9
# Comment se fait-il que je me sente bien lorsque mon taux de sucre atteint 39 HI ? 10
# Une meilleure alimentation permettrait-elle d'arrêter l'insuline ? 11
# Pourquoi ma glycémie fluctue-t-elle ?  12
# Y A-T-IL UN REMÈDE EN VUE ? 13
# ...

# %%
l=[14,15,17,18,19,42,48,49,65,75,76,]
